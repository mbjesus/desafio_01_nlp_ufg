# %% [markdown]
# # Trabalho NLP - Desafio 01

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import unicodedata
import re
import numpy as np
from time import time
from pprint import pprint

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 

nltk.download('stopwords')
nltk.download('punkt')


from nltk.stem import SnowballStemmer

from sklearn.utils import resample
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn import metrics


#modelos
from sklearn.linear_model import SGDClassifier
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mbjesus/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/mbjesus/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Etapa 1 - Obter dados Rotulados

# %%
dataset = pd.read_csv("dataset/train.csv")
datasetTeste = pd.read_csv("dataset/test.csv")

# %%
datasetTeste["id"] = datasetTeste.index
datasetTeste.head(10)
# Out:
#                                                title  id
# 0                      Strobo Mini Kit Com 5 Strobos   0
# 1                Filtro Hoya Hmc Uv(c) - Uv-hmc 72mm   1
# 2                 Dvd Next Lite (envio Toda Segunda)   2
# 3  Fim De Curso Tubinho Do  Motor Desl  Peccinin ...   3
# 4  Carro Infantil Smart Baby Reclinável Bandeiran...   4
# 5  Par Coifa Caixa Direção Hidraulica C4 Lounge 2...   5
# 6  Protetor Sofá Retrátil Reclinavél Com Assento ...   6
# 7           Pedal Behringer Tu300 Afinador Cromatico   7
# 8                             Receptor Satmax Elsys    8
# 9                             Mini Fantasia Noivinha   9

# %% [markdown]
# ## Etapa 2 - Pré-processamento

# %% [markdown]
# ### 2.1 - Converter para minúsculo

# %%
dataset["category"] = dataset["category"].str.lower()
dataset["title"] = dataset["title"].str.lower()
dataset.head(5)
# Out:
#                                                title  \
# 0        tampa para champanhe cromado ibili - 722500
# 1  copo térmico plástico os jetsons família espacial
# 2         nobreak sms bivolt 600va para pc ps4 xbox
# 3  led de balada rgb luz de palco dj disco strobo...
# 4  filtro de lente cpl 52mm kenko polarizador par...
#
#                     category
# 0                ice_buckets
# 1  thermal_cups_and_tumblers
# 2        stabilizers_and_ups
# 3           led_stage_lights
# 4               lens_filters

# %%
datasetTeste["title"] = datasetTeste["title"].str.lower()
datasetTeste.head(5)
# Out:
#                                                title  id
# 0                      strobo mini kit com 5 strobos   0
# 1                filtro hoya hmc uv(c) - uv-hmc 72mm   1
# 2                 dvd next lite (envio toda segunda)   2
# 3  fim de curso tubinho do  motor desl  peccinin ...   3
# 4  carro infantil smart baby reclinável bandeiran...   4

# %% [markdown]
# ### 2.2 - Remover caractéres especiais

# %%
##FUNCAO QUE REMOVE CARACTERES ESPECIAIS
def remover_acentos(texto):
    
    ##REMOVER ACENTOS
    texto = unicodedata.normalize('NFKD', texto).encode('ASCII', 'ignore').decode('ASCII')
    
    ##REMOVER CARACTERES ESPECIAIS
    texto = re.sub(r'[?|$|&|*|%|@|(|)|~|,|\.|:|\-|\'|/|+]', r' ', texto)
    
    ##REMOVER MEDIDAS
    texto = re.sub('(va)|(mm)|(km)|(cm)', r' ', texto)
    
    ##REMOVER NUMEROS QUE APARECEM ISOLADOS
    texto = re.sub('[\s][0-9]{1,}', ' ', texto)
    
     ##REMOVER TEXTOS COM ATE DOIS CARACTERES
    texto = re.sub(r'\b\w{1,2}\b', ' ', texto)
    
    return texto

# %%
#aplica limpeza no texto
dataset["title_normalizado"] = dataset["title"].map(remover_acentos)
dataset.head(5)
# Out:
#                                                title  \
# 0        tampa para champanhe cromado ibili - 722500
# 1  copo térmico plástico os jetsons família espacial
# 2         nobreak sms bivolt 600va para pc ps4 xbox
# 3  led de balada rgb luz de palco dj disco strobo...
# 4  filtro de lente cpl 52mm kenko polarizador par...
#
#                     category  \
# 0                ice_buckets
# 1  thermal_cups_and_tumblers
# 2        stabilizers_and_ups
# 3           led_stage_lights
# 4               lens_filters
#
#                                    title_normalizado
# 0              tampa para champanhe cromado ibili
# 1   copo termico plastico   jetsons familia espacial
# 2              nobreak sms bivolt   para   ps4 xbox
# 3  led   balada rgb luz   palco   disco strobo fe...
# 4  filtro   lente cpl   kenko polarizador para ob...

# %%
datasetTeste["title_normalizado"] = datasetTeste["title"].map(remover_acentos)
datasetTeste.head(5)
# Out:
#                                                title  id  \
# 0                      strobo mini kit com 5 strobos   0
# 1                filtro hoya hmc uv(c) - uv-hmc 72mm   1
# 2                 dvd next lite (envio toda segunda)   2
# 3  fim de curso tubinho do  motor desl  peccinin ...   3
# 4  carro infantil smart baby reclinável bandeiran...   4
#
#                                    title_normalizado
# 0                       strobo mini kit com  strobos
# 1                     filtro hoya hmc          hmc
# 2                 dvd next lite  envio toda segunda
# 3  fim   curso tubinho    motor desl  peccinin li...
# 4  carro infantil smart baby reclinavel bandeiran...

# %% [markdown]
# ### 2.3 - Remover Stop-words

# %%
def remove_stopwords(texto):
    #REMOVER STOPWORDS
    ##baixar stopwords
    stopwords = nltk.corpus.stopwords.words('portuguese')
    
    #gera tokens
    tokens = word_tokenize(texto)
    
    #remove stopwords
    filtered_tokens = [token.lower() for token in tokens if token not in stopwords]
    
    #retorna texto sem as stop-words
    return ' '.join(filtered_tokens)

# %%
#aplica remocao de stop-words
dataset["title_normalizado_sem_sw"] = dataset["title_normalizado"].map(remove_stopwords)
dataset.head(5)
# Out:
#                                                title  \
# 0        tampa para champanhe cromado ibili - 722500
# 1  copo térmico plástico os jetsons família espacial
# 2         nobreak sms bivolt 600va para pc ps4 xbox
# 3  led de balada rgb luz de palco dj disco strobo...
# 4  filtro de lente cpl 52mm kenko polarizador par...
#
#                     category  \
# 0                ice_buckets
# 1  thermal_cups_and_tumblers
# 2        stabilizers_and_ups
# 3           led_stage_lights
# 4               lens_filters
#
#                                    title_normalizado  \
# 0              tampa para champanhe cromado ibili
# 1   copo termico plastico   jetsons familia espacial
# 2              nobreak sms bivolt   para   ps4 xbox
# 3  led   balada rgb luz   palco   disco strobo fe...
# 4  filtro   lente cpl   kenko polarizador para ob...
#
#                             title_normalizado_sem_sw
# 0                      tampa champanhe cromado ibili
# 1     copo termico plastico jetsons familia espacial
# 2                        nobreak sms bivolt ps4 xbox
# 3  led balada rgb luz palco disco strobo festa ba...
# 4          filtro lente cpl kenko polarizador objeti

# %%
datasetTeste["title_normalizado_sem_sw"] = datasetTeste["title_normalizado"].map(remove_stopwords)
datasetTeste.head(5)
# Out:
#                                                title  id  \
# 0                      strobo mini kit com 5 strobos   0
# 1                filtro hoya hmc uv(c) - uv-hmc 72mm   1
# 2                 dvd next lite (envio toda segunda)   2
# 3  fim de curso tubinho do  motor desl  peccinin ...   3
# 4  carro infantil smart baby reclinável bandeiran...   4
#
#                                    title_normalizado  \
# 0                       strobo mini kit com  strobos
# 1                     filtro hoya hmc          hmc
# 2                 dvd next lite  envio toda segunda
# 3  fim   curso tubinho    motor desl  peccinin li...
# 4  carro infantil smart baby reclinavel bandeiran...
#
#                             title_normalizado_sem_sw
# 0                            strobo mini kit strobos
# 1                                filtro hoya hmc hmc
# 2                   dvd next lite envio toda segunda
# 3  fim curso tubinho motor desl peccinin light super
# 4  carro infantil smart baby reclinavel bandeiran...

# %% [markdown]
# ### 2.4 - Transformar para Radical

# %%
def stemmer_sentenca(texto):
    
    #baixa dados
    pt_stemmer = SnowballStemmer('portuguese')
    
    #divide em tokens
    tokens = word_tokenize(texto)
    
    #aplica stemmer
    lista_stem = [pt_stemmer.stem(token) for token in tokens ]
    
    #retorna texto 
    return ' '.join(lista_stem)

# %%
#aplica limpeza stemmer
dataset["title_normalizado_sem_sw_stemmer"] = dataset["title_normalizado_sem_sw"].map(stemmer_sentenca)
dataset.head(5)
# Out:
#                                                title  \
# 0        tampa para champanhe cromado ibili - 722500
# 1  copo térmico plástico os jetsons família espacial
# 2         nobreak sms bivolt 600va para pc ps4 xbox
# 3  led de balada rgb luz de palco dj disco strobo...
# 4  filtro de lente cpl 52mm kenko polarizador par...
#
#                     category  \
# 0                ice_buckets
# 1  thermal_cups_and_tumblers
# 2        stabilizers_and_ups
# 3           led_stage_lights
# 4               lens_filters
#
#                                    title_normalizado  \
# 0              tampa para champanhe cromado ibili
# 1   copo termico plastico   jetsons familia espacial
# 2              nobreak sms bivolt   para   ps4 xbox
# 3  led   balada rgb luz   palco   disco strobo fe...
# 4  filtro   lente cpl   kenko polarizador para ob...
#
#                             title_normalizado_sem_sw  \
# 0                      tampa champanhe cromado ibili
# 1     copo termico plastico jetsons familia espacial
# 2                        nobreak sms bivolt ps4 xbox
# 3  led balada rgb luz palco disco strobo festa ba...
# 4          filtro lente cpl kenko polarizador objeti
#
#             title_normalizado_sem_sw_stemmer
# 0                    tamp champanh crom ibil
# 1  cop termic plastic jetsons famil espacial
# 2                nobreak sms bivolt ps4 xbox
# 3   led bal rgb luz palc disc strob fest bal
# 4          filtr lent cpl kenk polariz objet

# %%
datasetTeste["title_normalizado_sem_sw_stemmer"] = datasetTeste["title_normalizado_sem_sw"].map(stemmer_sentenca)
datasetTeste.head(5)
# Out:
#                                                title  id  \
# 0                      strobo mini kit com 5 strobos   0
# 1                filtro hoya hmc uv(c) - uv-hmc 72mm   1
# 2                 dvd next lite (envio toda segunda)   2
# 3  fim de curso tubinho do  motor desl  peccinin ...   3
# 4  carro infantil smart baby reclinável bandeiran...   4
#
#                                    title_normalizado  \
# 0                       strobo mini kit com  strobos
# 1                     filtro hoya hmc          hmc
# 2                 dvd next lite  envio toda segunda
# 3  fim   curso tubinho    motor desl  peccinin li...
# 4  carro infantil smart baby reclinavel bandeiran...
#
#                             title_normalizado_sem_sw  \
# 0                            strobo mini kit strobos
# 1                                filtro hoya hmc hmc
# 2                   dvd next lite envio toda segunda
# 3  fim curso tubinho motor desl peccinin light super
# 4  carro infantil smart baby reclinavel bandeiran...
#
#                   title_normalizado_sem_sw_stemmer
# 0                              strob min kit strob
# 1                                filtr hoy hmc hmc
# 2                     dvd next lit envi tod segund
# 3    fim curs tubinh motor desl peccinin light sup
# 4  carr infantil smart baby reclinavel bandeir ros

# %% [markdown]
# ### 2.5 - Balancear Dados com Uper-Undersampling

# %%
def balencearMesmaClasse(df_desbalanceado,tamanho):
        
    lista_categorias = df_desbalanceado.category.unique()
        
    df_sampled = pd.DataFrame()

    for categoria in lista_categorias:

        df_tmp = df_desbalanceado[df_desbalanceado.category == categoria]

        if(len(df_tmp)) > tamanho:
            ##como a classe tem mais registros que o tamanho, fazer SEM repeticao
            df_tmp = resample(df_tmp, 
                             replace=False,    
                             n_samples=(tamanho),    
                             random_state=123) 
        else:
            ##como a classe tem mais registros que o tamanho, fazer COM repeticao
            df_tmp = resample(df_tmp, 
                             replace=True,    
                             n_samples=(tamanho),    
                             random_state=123)

        df_sampled = pd.concat([df_sampled, df_tmp])

    return df_sampled

# %%
dataset_balanceado = balencearMesmaClasse(dataset,370)
dataset_balanceado.head(5)
# Out:
#                                                    title     category  \
# 20135  balde de gelo acrílico p/ cerveja 5l baldinho ...  ice_buckets
# 3343   cervegela c/ refil de congelamento 2h mantém c...  ice_buckets
# 24862        balde brahma com alça e abridor de garrafas  ice_buckets
# 14064  kit c/ 6 balde plástico reforçado plasnew 20 l...  ice_buckets
# 27396           **balde brahma  - luminoso de brinde!!!!  ice_buckets
#
#                                        title_normalizado  \
# 20135  balde   gelo acrilico    cerveja   baldinho ge...
# 3343   cervegela    refil   congelamento   mantem cer...
# 24862         balde brahma com alca   abridor   garrafas
# 14064   kit     balde plastico reforcado plasnew  litros
# 27396              balde brahma    luminoso   brinde!!!!
#
#                                 title_normalizado_sem_sw  \
# 20135    balde gelo acrilico cerveja baldinho gelo latas
# 3343   cervegela refil congelamento mantem cerveja ge...
# 24862                 balde brahma alca abridor garrafas
# 14064        kit balde plastico reforcado plasnew litros
# 27396               balde brahma luminoso brinde ! ! ! !
#
#             title_normalizado_sem_sw_stemmer
# 20135  bald gel acril cervej baldinh gel lat
# 3343   cervegel refil congel mant cervej gel
# 24862         bald brahm alca abridor garraf
# 14064   kit bald plastic reforc plasnew litr
# 27396         bald brahm lumin brind ! ! ! !

# %%
dataset_balanceado.shape
# Out:
# (30710, 5)

# %%
dataset.shape
# Out:
# (33500, 5)

# %%
###Separar os dados em treino e teste """
X_train, X_test, y_train, y_test = train_test_split(dataset_balanceado["title_normalizado_sem_sw_stemmer"], 
                                                    dataset_balanceado["category"], 
                                                    test_size=0.3, random_state = 0)

#CONSTRUIR MATRIZ ESPARSA """ 
count_vect = CountVectorizer(max_df= 0.5,
                            max_features= None,
                            min_df= 1,
                            ngram_range= (1, 2))

#fazer fit_transoform (vetor de palavras) para os dados de treino """
X_train_counts = count_vect.fit_transform(X_train)

#ponderar palavras mais frequentes  """
tf_transformer = TfidfTransformer(norm= 'l2',
                                  use_idf= True)
X_train_tf = tf_transformer.fit_transform(X_train_counts)

'''
Melhor score: 0.956
Melhores Parametros:
	clf__alpha: 1e-05
	clf__max_iter: 80
	clf__penalty: 'l2'
	tfidf__norm: 'l2'
	tfidf__use_idf: True
	vect__max_df: 0.5
	vect__max_features: None
	vect__min_df: 1
	vect__ngram_range: (1, 2)
       '''
# Out:
# "\nMelhor score: 0.956\nMelhores Parametros:\n\tclf__alpha: 1e-05\n\tclf__max_iter: 80\n\tclf__penalty: 'l2'\n\ttfidf__norm: 'l2'\n\ttfidf__use_idf: True\n\tvect__max_df: 0.5\n\tvect__max_features: None\n\tvect__min_df: 1\n\tvect__ngram_range: (1, 2)\n       "

# %% [markdown]
# ## Etapa 3 - Aplicar aprendizado de máquina

# %%
sgd = SGDClassifier(penalty='l2',
                    alpha=1e-05, 
                    max_iter=80)

#treinar modelo
t0 = time()
clf = sgd.fit(X_train_tf, y_train)
print("Fit done in %0.3fs" % (time() - t0))
y_pred_modelo = clf.predict(count_vect.transform(X_test))
print("Pred done in %0.3fs" % (time() - t0))
# Out:
# Fit done in 1.189s
# Pred done in 1.339s

# %% [markdown]
# ### Calcular desempenho

# %%
print(metrics.classification_report(y_test, y_pred_modelo, target_names=dataset_balanceado["category"].unique()))
# Out:
#                                 precision    recall  f1-score   support
#
#                    ice_buckets       0.96      0.88      0.91        98
#      thermal_cups_and_tumblers       0.95      0.94      0.95       104
#            stabilizers_and_ups       0.94      0.94      0.94       110
#               led_stage_lights       0.90      0.93      0.92       120
#                   lens_filters       0.97      0.99      0.98       105
#           engine_oil_dipsticks       0.93      0.94      0.93       105
#                  roller_skates       0.98      0.96      0.97       113
#                    pool_lights       0.92      0.89      0.91       110
#                      key_racks       0.93      0.86      0.89       122
#                    tv_antennas       0.91      0.92      0.91       111
#             motorcycle_fenders       0.98      0.92      0.95       106
#             soldering_machines       0.94      0.94      0.94       110
#           motorcycle_batteries       0.91      0.99      0.95       114
#           car_distributor_caps       0.96      0.94      0.95       119
#                 dj_controllers       0.96      0.94      0.95       115
#                   av_receivers       0.94      0.94      0.94        97
#                 musical_tuners       0.93      0.99      0.96        95
#                     tool_boxes       0.98      0.97      0.98       113
#  electronic_entrance_intercoms       0.98      0.94      0.96       124
#                      sway_bars       1.00      0.98      0.99       121
#                    gate_motors       0.97      0.95      0.96       117
#                   home_shelves       0.97      0.93      0.95       121
#                   erotic_pumps       0.94      0.93      0.94       119
#             motorcycle_jerseys       0.96      0.99      0.98       104
#               aquarium_filters       1.00      0.97      0.99       107
#           car_engine_camshafts       0.98      0.99      0.99       114
#                   clutch_forks       0.96      0.90      0.93       120
#     cellphone_repair_tool_kits       0.85      0.99      0.92       106
#                     party_hats       0.96      0.99      0.97       114
#                      bookcases       0.99      0.99      0.99       105
#                    pet_collars       0.99      0.96      0.98       109
#                      suitcases       0.97      1.00      0.98       120
#  cellphone_replacement_cameras       0.98      0.97      0.97       124
#                   men_swimwear       0.94      0.96      0.95       119
#                   hair_brushes       0.96      0.89      0.92       103
#      tv_receivers_and_decoders       0.99      0.97      0.98       118
#                          irons       0.97      0.97      0.97       115
#             bicycle_handlebars       0.95      0.97      0.96       129
#                makeup_removers       0.97      0.98      0.98       106
#                       lighters       0.88      0.86      0.87       109
#          motorcycle_crash_bars       0.97      0.94      0.96       108
#                         flutes       0.81      0.86      0.83       106
#          vehicle_clutch_cables       0.95      0.97      0.96       107
#                car_door_hinges       0.86      0.90      0.88       105
#                camera_chargers       1.00      0.97      0.99       104
#                protection_nets       0.92      0.90      0.91       106
#              intercooler_hoses       0.91      0.98      0.94       122
#                wheels_bearings       1.00      0.88      0.94       102
#                    toilet_rugs       0.98      0.99      0.99       129
#      motorcycle_starter_motors       0.99      0.97      0.98       102
#                      cv_joints       0.91      0.79      0.85       101
# engine_valves_spring_retainers       0.95      0.99      0.97       105
#                    crankshafts       0.93      0.97      0.95       118
#                       cachacas       0.96      0.97      0.97       106
#                electric_drills       0.99      0.98      0.99       103
#               battery_chargers       0.98      0.94      0.96       115
#                    toothpastes       0.94      0.98      0.96       123
#                            gps       0.93      0.98      0.96        98
#                 hand_polishers       0.98      0.98      0.98       118
#             cd_and_dvd_players       0.95      0.99      0.97       100
#                   gun_holsters       0.96      0.96      0.96       109
#                          cribs       0.90      0.97      0.93       100
#                   toilet_seats       0.94      0.94      0.94       120
#          sofa_and_futon_covers       0.87      0.95      0.91       107
#      engine_cooling_fan_motors       0.94      0.90      0.92       113
#                          pants       0.99      0.95      0.97       110
#                 baby_car_seats       0.98      0.94      0.96       104
#         car_ac_hose_assemblies       0.98      0.99      0.98       119
#                         straws       0.99      0.93      0.96       107
#                     gym_gloves       0.96      0.98      0.97       122
#    car_engine_camshaft_sensors       0.97      0.99      0.98       111
#            kitchen_range_hoods       0.97      1.00      0.99       112
#                erotic_costumes       0.95      0.99      0.97       108
#                       padlocks       0.97      0.97      0.97       114
#                   dried_fruits       0.99      0.99      0.99       100
# dog_carriers_and_carrying_bags       0.97      0.98      0.97       117
#           push_and_riding_toys       0.89      0.96      0.92        96
#               car_intercoolers       0.96      0.83      0.89       117
#           power_steering_hoses       0.93      0.91      0.92       113
#                   toothbrushes       0.96      0.95      0.95        99
#         desktop_computer_cases       0.92      0.95      0.93       110
#                       scooters       0.92      0.96      0.94       114
#               microcontrollers       0.95      0.98      0.96       122
#
#                       accuracy                           0.95      9213
#                      macro avg       0.95      0.95      0.95      9213
#                   weighted avg       0.95      0.95      0.95      9213

# %% [markdown]
# # Aplicar modelo nos dados de Teste

# %%
##Visao dos dados de Teste
datasetTeste.head(5)
# Out:
#                                                title  id  \
# 0                      strobo mini kit com 5 strobos   0
# 1                filtro hoya hmc uv(c) - uv-hmc 72mm   1
# 2                 dvd next lite (envio toda segunda)   2
# 3  fim de curso tubinho do  motor desl  peccinin ...   3
# 4  carro infantil smart baby reclinável bandeiran...   4
#
#                                    title_normalizado  \
# 0                       strobo mini kit com  strobos
# 1                     filtro hoya hmc          hmc
# 2                 dvd next lite  envio toda segunda
# 3  fim   curso tubinho    motor desl  peccinin li...
# 4  carro infantil smart baby reclinavel bandeiran...
#
#                             title_normalizado_sem_sw  \
# 0                            strobo mini kit strobos
# 1                                filtro hoya hmc hmc
# 2                   dvd next lite envio toda segunda
# 3  fim curso tubinho motor desl peccinin light super
# 4  carro infantil smart baby reclinavel bandeiran...
#
#                   title_normalizado_sem_sw_stemmer
# 0                              strob min kit strob
# 1                                filtr hoy hmc hmc
# 2                     dvd next lit envi tod segund
# 3    fim curs tubinh motor desl peccinin light sup
# 4  carr infantil smart baby reclinavel bandeir ros

# %% [markdown]
# ### Aplicando predição

# %%
y_pred_modelo_final = clf.predict(count_vect.transform(datasetTeste["title_normalizado_sem_sw_stemmer"]))

# %%
data_setPredito = pd.DataFrame(y_pred_modelo_final,columns=["category"])
data_setPredito.head(10)
# Out:
#                     category
# 0           led_stage_lights
# 1               lens_filters
# 2         cd_and_dvd_players
# 3                gate_motors
# 4       push_and_riding_toys
# 5       power_steering_hoses
# 6      sofa_and_futon_covers
# 7             musical_tuners
# 8  tv_receivers_and_decoders
# 9            erotic_costumes

# %%
##Transformar em Data-Frame
data_setPredito['id'] = data_setPredito.index
data_setPredito['category'] = data_setPredito['category'].str.upper()
submissao = data_setPredito[["id","category"]] 

## Salvar no formato de submissao 
submissao.to_csv("submissao.csv", index = None, header=True)
submissao.head(10)
# Out:
#    id                   category
# 0   0           LED_STAGE_LIGHTS
# 1   1               LENS_FILTERS
# 2   2         CD_AND_DVD_PLAYERS
# 3   3                GATE_MOTORS
# 4   4       PUSH_AND_RIDING_TOYS
# 5   5       POWER_STEERING_HOSES
# 6   6      SOFA_AND_FUTON_COVERS
# 7   7             MUSICAL_TUNERS
# 8   8  TV_RECEIVERS_AND_DECODERS
# 9   9            EROTIC_COSTUMES

# %% [markdown]
# ### Gerando visualizacão amigável

# %%
visualizacaoResutado =   pd.merge(datasetTeste[["title","id"]],
                         data_setPredito[["id","category"]],
                         on='id')
visualizacaoResutado.head(200)
# Out:
#                                                  title   id  \
# 0                        strobo mini kit com 5 strobos    0
# 1                  filtro hoya hmc uv(c) - uv-hmc 72mm    1
# 2                   dvd next lite (envio toda segunda)    2
# 3    fim de curso tubinho do  motor desl  peccinin ...    3
# 4    carro infantil smart baby reclinável bandeiran...    4
# 5    par coifa caixa direção hidraulica c4 lounge 2...    5
# 6    protetor sofá retrátil reclinavél com assento ...    6
# 7             pedal behringer tu300 afinador cromatico    7
# 8                               receptor satmax elsys     8
# 9                               mini fantasia noivinha    9
# 10   rede p/proteção de cama elastica 4.00 mts c/2 ...   10
# 11   coldre cueca + abdominal elástico axilar velad...   11
# 12   placa de comando para motor de portão  rcg com...   12
# 13                        casa de cachorro linguiçinha   13
# 14   carregador de bateria lp-e5 canon eos 450d 500...   14
# 15   fonte carregador original sony ac-l200 dcr-hc5...   15
# 16   camera traseira g4 play xt1626 original retira...   16
# 17                 motor arranque cbx 250 twister 2007   17
# 18   flauta transversal harmony tbfl-6248.em dó c/c...   18
# 19   gaiola comando valvula prisma cobalt spin 1.4 ...   19
# 20   kit c/ 2 creme dental close up white attractio...   20
# 21      3 jogo de banheiro tear pintado 3 pcs atacado    21
# 22   calço carroceria (coxinho) pu 1 pol rural pick...   22
# 23    cabo de embreagem honda crf 230 todas - br parts   23
# 24                rastreador sem mensalidade fortaleza   24
# 25   antena sinal digital para televisão, pronta en...   25
# 26   kit carenagem com protetor xre 300 branco pero...   26
# 27      denon avr 591 - high resolution surround sound   27
# 28       capa protetora de sofá 3 e 2 lugares vermelho   28
# 29                       escova dental torcedor santos   29
# ..                                                 ...  ...
# 170  kit rolamento roda traseiro kia besta 92/04 as...  170
# 171  retentor valvula + cabeçote    amarok tdi (201...  171
# 172           flex camera frontal motorola moto c plus  172
# 173      funil vareta do nivel de oleo polo 06a103663a  173
# 174                                 calça jeans hiatto  174
# 175  camiseta alpinestars feminina ageless tank pre...  175
# 176  mini veiculo pick-up elétrica guchao grande - ...  176
# 177                camiseta dakar dust rider off white  177
# 178  caixa mini maçarico 40 unidades recarregavel t...  178
# 179  berço mini cama baby branco brilho, padrão ame...  179
# 180  kit interfone coletivo intelbras 38 pontos com...  180
# 181         coldre tático nylon 24/7 uso velado /preto  181
# 182           guarda pó do garfo da embreagem do opala  182
# 183  growler 2l  lei da pureza  para  chopp e cerve...  183
# 184  aparelho bomba peniana controle anel ce capa p...  184
# 185  kit antena mini maria mole + par. fixador + su...  185
# 186                3 vaporizadores de ervas gpen elite  186
# 187  kit refletor piscina 3 iluminação led 45 color...  187
# 188  porteiro eletrônico residencial ipr8000 intelb...  188
# 189  tampa de vaso square preto para bacia incepa c...  189
# 190       garfo do câmbio do niva e laika - peças lada  190
# 191  intercooler volkswagen 16-220 4x2 cum 6ctaa 22...  191
# 192              cofre gatinho ladrão (pronta entrega)  192
# 193  kit 15 sungas boxer adulto moda praia lycra at...  193
# 194  carregador super rápido bap-551 com 4 baterias...  194
# 195  promoção capa protetor de sofa  2 e 3 lugares ...  195
# 196  dvd aikon akdv-3000 dvd/ cd/ mp3/ mp4/ usb/ wm...  196
# 197  virabrequim kia cerato 1.6 16v 2014 a 2015 - 3...  197
# 198                                   caldeira ws-2035  198
# 199               patins rolller proficional numero 34  199
#
#                            category
# 0                  LED_STAGE_LIGHTS
# 1                      LENS_FILTERS
# 2                CD_AND_DVD_PLAYERS
# 3                       GATE_MOTORS
# 4              PUSH_AND_RIDING_TOYS
# 5              POWER_STEERING_HOSES
# 6             SOFA_AND_FUTON_COVERS
# 7                    MUSICAL_TUNERS
# 8         TV_RECEIVERS_AND_DECODERS
# 9                   EROTIC_COSTUMES
# 10                  PROTECTION_NETS
# 11                     GUN_HOLSTERS
# 12                      GATE_MOTORS
# 13   DOG_CARRIERS_AND_CARRYING_BAGS
# 14                  CAMERA_CHARGERS
# 15                  CAMERA_CHARGERS
# 16    CELLPHONE_REPLACEMENT_CAMERAS
# 17        MOTORCYCLE_STARTER_MOTORS
# 18                           FLUTES
# 19             CAR_ENGINE_CAMSHAFTS
# 20                      TOOTHPASTES
# 21                      TOILET_RUGS
# 22                            PANTS
# 23            VEHICLE_CLUTCH_CABLES
# 24                              GPS
# 25                      TV_ANTENNAS
# 26               MOTORCYCLE_FENDERS
# 27                     AV_RECEIVERS
# 28            SOFA_AND_FUTON_COVERS
# 29                     TOOTHBRUSHES
# ..                              ...
# 170                 WHEELS_BEARINGS
# 171  ENGINE_VALVES_SPRING_RETAINERS
# 172   CELLPHONE_REPLACEMENT_CAMERAS
# 173            ENGINE_OIL_DIPSTICKS
# 174                           PANTS
# 175              MOTORCYCLE_JERSEYS
# 176            PUSH_AND_RIDING_TOYS
# 177              MOTORCYCLE_JERSEYS
# 178                        LIGHTERS
# 179                           CRIBS
# 180   ELECTRONIC_ENTRANCE_INTERCOMS
# 181                    GUN_HOLSTERS
# 182                    CLUTCH_FORKS
# 183                     ICE_BUCKETS
# 184                    EROTIC_PUMPS
# 185                     TV_ANTENNAS
# 186                           IRONS
# 187                     POOL_LIGHTS
# 188   ELECTRONIC_ENTRANCE_INTERCOMS
# 189                    TOILET_SEATS
# 190                    CLUTCH_FORKS
# 191                CAR_INTERCOOLERS
# 192                     PET_COLLARS
# 193                    MEN_SWIMWEAR
# 194                BATTERY_CHARGERS
# 195           SOFA_AND_FUTON_COVERS
# 196              CD_AND_DVD_PLAYERS
# 197                     CRANKSHAFTS
# 198                           IRONS
# 199                   ROLLER_SKATES
#
# [200 rows x 3 columns]

# %% [markdown]
# # FIM
