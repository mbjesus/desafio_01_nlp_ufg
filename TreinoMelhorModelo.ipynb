# %% [markdown]
# # Trabalho NLP - Desafio 01

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import unicodedata
import re
import numpy as np
from time import time
from pprint import pprint

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 

nltk.download('stopwords')
nltk.download('punkt')


from nltk.stem import SnowballStemmer

from sklearn.utils import resample
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

#modelos
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import MultinomialNB
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mbjesus/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/mbjesus/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Etapa 1 - Obter dados Rotulados

# %%
dataset = pd.read_csv("dataset/train.csv")
datasetTeste = pd.read_csv("dataset/test.csv")

# %%
datasetTeste["id"] = datasetTeste.index
datasetTeste.head(10)
# Out:
#                                                title  id
# 0                      Strobo Mini Kit Com 5 Strobos   0
# 1                Filtro Hoya Hmc Uv(c) - Uv-hmc 72mm   1
# 2                 Dvd Next Lite (envio Toda Segunda)   2
# 3  Fim De Curso Tubinho Do  Motor Desl  Peccinin ...   3
# 4  Carro Infantil Smart Baby Reclinável Bandeiran...   4
# 5  Par Coifa Caixa Direção Hidraulica C4 Lounge 2...   5
# 6  Protetor Sofá Retrátil Reclinavél Com Assento ...   6
# 7           Pedal Behringer Tu300 Afinador Cromatico   7
# 8                             Receptor Satmax Elsys    8
# 9                             Mini Fantasia Noivinha   9

# %% [markdown]
# ## Etapa 2 - Pré-processamento

# %% [markdown]
# ### 2.1 - Converter para minúsculo

# %%
dataset["category"] = dataset["category"].str.lower()
dataset["title"] = dataset["title"].str.lower()
dataset.head(5)
# Out:
#                                                title  \
# 0        tampa para champanhe cromado ibili - 722500
# 1  copo térmico plástico os jetsons família espacial
# 2         nobreak sms bivolt 600va para pc ps4 xbox
# 3  led de balada rgb luz de palco dj disco strobo...
# 4  filtro de lente cpl 52mm kenko polarizador par...
#
#                     category
# 0                ice_buckets
# 1  thermal_cups_and_tumblers
# 2        stabilizers_and_ups
# 3           led_stage_lights
# 4               lens_filters

# %%
datasetTeste["title"] = datasetTeste["title"].str.lower()
datasetTeste.head(5)
# Out:
#                                                title  id
# 0                      strobo mini kit com 5 strobos   0
# 1                filtro hoya hmc uv(c) - uv-hmc 72mm   1
# 2                 dvd next lite (envio toda segunda)   2
# 3  fim de curso tubinho do  motor desl  peccinin ...   3
# 4  carro infantil smart baby reclinável bandeiran...   4

# %% [markdown]
# ### 2.2 - Remover caractéres especiais

# %%
##FUNCAO QUE REMOVE CARACTERES ESPECIAIS
def remover_acentos(texto):
    
    ##REMOVER ACENTOS
    #texto = unicodedata.normalize('NFKD', texto).encode('ASCII', 'ignore').decode('ASCII')
    
    ##REMOVER CARACTERES ESPECIAIS
    texto = re.sub(r'[?|!|$|&|*|%|@|(|)|~|,|\.|:|\-|\'|/|+]', r' ', texto)
    
    ##REMOVER MEDIDAS
    texto = re.sub('(va)|(mm)|(km)|(cm)', r' ', texto)
    
    ##REMOVER NUMEROS QUE APARECEM ISOLADOS
    texto = re.sub('[\s][0-9]{1,}', ' ', texto)
    
     ##REMOVER TEXTOS COM ATE DOIS CARACTERES
    texto = re.sub(r'\b\w{1,2}\b', ' ', texto)
    
    return texto

# %%
#aplica limpeza no texto
dataset["title_normalizado"] = dataset["title"].map(remover_acentos)
dataset.head(5)
# Out:
#                                                title  \
# 0        tampa para champanhe cromado ibili - 722500
# 1  copo térmico plástico os jetsons família espacial
# 2         nobreak sms bivolt 600va para pc ps4 xbox
# 3  led de balada rgb luz de palco dj disco strobo...
# 4  filtro de lente cpl 52mm kenko polarizador par...
#
#                     category  \
# 0                ice_buckets
# 1  thermal_cups_and_tumblers
# 2        stabilizers_and_ups
# 3           led_stage_lights
# 4               lens_filters
#
#                                    title_normalizado  \
# 0              tampa para champanhe cromado ibili
# 1   copo térmico plástico   jetsons família espacial
# 2              nobreak sms bivolt   para   ps4 xbox
# 3  led   balada rgb luz   palco   disco strobo fe...
# 4  filtro   lente cpl   kenko polarizador para ob...
#
#                             title_normalizado_sem_sw  \
# 0                      tampa champanhe cromado ibili
# 1     copo termico plastico jetsons familia espacial
# 2                        nobreak sms bivolt ps4 xbox
# 3  led balada rgb luz palco disco strobo festa ba...
# 4          filtro lente cpl kenko polarizador objeti
#
#             title_normalizado_sem_sw_stemmer
# 0                    tamp champanh crom ibil
# 1  cop termic plastic jetsons famil espacial
# 2                nobreak sms bivolt ps4 xbox
# 3   led bal rgb luz palc disc strob fest bal
# 4          filtr lent cpl kenk polariz objet

# %%
datasetTeste["title_normalizado"] = datasetTeste["title"].map(remover_acentos)
datasetTeste.head(5)
# Out:
#                                                title  id  \
# 0                      strobo mini kit com 5 strobos   0
# 1                filtro hoya hmc uv(c) - uv-hmc 72mm   1
# 2                 dvd next lite (envio toda segunda)   2
# 3  fim de curso tubinho do  motor desl  peccinin ...   3
# 4  carro infantil smart baby reclinável bandeiran...   4
#
#                                    title_normalizado  \
# 0                       strobo mini kit com  strobos
# 1                     filtro hoya hmc          hmc
# 2                 dvd next lite  envio toda segunda
# 3  fim   curso tubinho    motor desl  peccinin li...
# 4  carro infantil smart baby reclinável bandeiran...
#
#                             title_normalizado_sem_sw  \
# 0                            strobo mini kit strobos
# 1                                filtro hoya hmc hmc
# 2                   dvd next lite envio toda segunda
# 3  fim curso tubinho motor desl peccinin light super
# 4  carro infantil smart baby reclinavel bandeiran...
#
#                   title_normalizado_sem_sw_stemmer
# 0                              strob min kit strob
# 1                                filtr hoy hmc hmc
# 2                     dvd next lit envi tod segund
# 3    fim curs tubinh motor desl peccinin light sup
# 4  carr infantil smart baby reclinavel bandeir ros

# %% [markdown]
# ### 2.3 - Remover Stop-words

# %%
def remove_stopwords(texto):
    #REMOVER STOPWORDS
    ##baixar stopwords
    stopwords = nltk.corpus.stopwords.words('portuguese')
    
    #gera tokens
    tokens = word_tokenize(texto)
    
    #remove stopwords
    filtered_tokens = [token.lower() for token in tokens if token not in stopwords]
    
    #retorna texto sem as stop-words
    return ' '.join(filtered_tokens)

# %%
#aplica remocao de stop-words
dataset["title_normalizado_sem_sw"] = dataset["title_normalizado"].map(remove_stopwords)
dataset.head(5)
# Out:
#                                                title  \
# 0        tampa para champanhe cromado ibili - 722500
# 1  copo térmico plástico os jetsons família espacial
# 2         nobreak sms bivolt 600va para pc ps4 xbox
# 3  led de balada rgb luz de palco dj disco strobo...
# 4  filtro de lente cpl 52mm kenko polarizador par...
#
#                     category  \
# 0                ice_buckets
# 1  thermal_cups_and_tumblers
# 2        stabilizers_and_ups
# 3           led_stage_lights
# 4               lens_filters
#
#                                    title_normalizado  \
# 0              tampa para champanhe cromado ibili
# 1   copo térmico plástico   jetsons família espacial
# 2              nobreak sms bivolt   para   ps4 xbox
# 3  led   balada rgb luz   palco   disco strobo fe...
# 4  filtro   lente cpl   kenko polarizador para ob...
#
#                             title_normalizado_sem_sw  \
# 0                      tampa champanhe cromado ibili
# 1     copo térmico plástico jetsons família espacial
# 2                        nobreak sms bivolt ps4 xbox
# 3  led balada rgb luz palco disco strobo festa ba...
# 4          filtro lente cpl kenko polarizador objeti
#
#             title_normalizado_sem_sw_stemmer
# 0                    tamp champanh crom ibil
# 1  cop termic plastic jetsons famil espacial
# 2                nobreak sms bivolt ps4 xbox
# 3   led bal rgb luz palc disc strob fest bal
# 4          filtr lent cpl kenk polariz objet

# %%
datasetTeste["title_normalizado_sem_sw"] = datasetTeste["title_normalizado"].map(remove_stopwords)
datasetTeste.head(5)
# Out:
#                                                title  id  \
# 0                      strobo mini kit com 5 strobos   0
# 1                filtro hoya hmc uv(c) - uv-hmc 72mm   1
# 2                 dvd next lite (envio toda segunda)   2
# 3  fim de curso tubinho do  motor desl  peccinin ...   3
# 4  carro infantil smart baby reclinável bandeiran...   4
#
#                                    title_normalizado  \
# 0                       strobo mini kit com  strobos
# 1                     filtro hoya hmc          hmc
# 2                 dvd next lite  envio toda segunda
# 3  fim   curso tubinho    motor desl  peccinin li...
# 4  carro infantil smart baby reclinável bandeiran...
#
#                             title_normalizado_sem_sw  \
# 0                            strobo mini kit strobos
# 1                                filtro hoya hmc hmc
# 2                   dvd next lite envio toda segunda
# 3  fim curso tubinho motor desl peccinin light super
# 4  carro infantil smart baby reclinável bandeiran...
#
#                   title_normalizado_sem_sw_stemmer
# 0                              strob min kit strob
# 1                                filtr hoy hmc hmc
# 2                     dvd next lit envi tod segund
# 3    fim curs tubinh motor desl peccinin light sup
# 4  carr infantil smart baby reclinavel bandeir ros

# %% [markdown]
# ### 2.4 - Transformar para Radical

# %%
def stemmer_sentenca(texto):
    
    #baixa dados
    pt_stemmer = SnowballStemmer('portuguese')
    
    #divide em tokens
    tokens = word_tokenize(texto)
    
    #aplica stemmer
    lista_stem = [pt_stemmer.stem(token) for token in tokens ]
    
    #retorna texto 
    return ' '.join(lista_stem)

# %%
#aplica limpeza stemmer
dataset["title_normalizado_sem_sw_stemmer"] = dataset["title_normalizado_sem_sw"].map(stemmer_sentenca)
dataset.head(5)
# Out:
#                                                title  \
# 0        tampa para champanhe cromado ibili - 722500
# 1  copo térmico plástico os jetsons família espacial
# 2         nobreak sms bivolt 600va para pc ps4 xbox
# 3  led de balada rgb luz de palco dj disco strobo...
# 4  filtro de lente cpl 52mm kenko polarizador par...
#
#                     category  \
# 0                ice_buckets
# 1  thermal_cups_and_tumblers
# 2        stabilizers_and_ups
# 3           led_stage_lights
# 4               lens_filters
#
#                                    title_normalizado  \
# 0              tampa para champanhe cromado ibili
# 1   copo térmico plástico   jetsons família espacial
# 2              nobreak sms bivolt   para   ps4 xbox
# 3  led   balada rgb luz   palco   disco strobo fe...
# 4  filtro   lente cpl   kenko polarizador para ob...
#
#                             title_normalizado_sem_sw  \
# 0                      tampa champanhe cromado ibili
# 1     copo térmico plástico jetsons família espacial
# 2                        nobreak sms bivolt ps4 xbox
# 3  led balada rgb luz palco disco strobo festa ba...
# 4          filtro lente cpl kenko polarizador objeti
#
#             title_normalizado_sem_sw_stemmer
# 0                    tamp champanh crom ibil
# 1  cop térmic plástic jetsons famíl espacial
# 2                nobreak sms bivolt ps4 xbox
# 3   led bal rgb luz palc disc strob fest bal
# 4          filtr lent cpl kenk polariz objet

# %%
datasetTeste["title_normalizado_sem_sw_stemmer"] = datasetTeste["title_normalizado_sem_sw"].map(stemmer_sentenca)
datasetTeste.head(5)
# Out:
#                                                title  id  \
# 0                      strobo mini kit com 5 strobos   0
# 1                filtro hoya hmc uv(c) - uv-hmc 72mm   1
# 2                 dvd next lite (envio toda segunda)   2
# 3  fim de curso tubinho do  motor desl  peccinin ...   3
# 4  carro infantil smart baby reclinável bandeiran...   4
#
#                                    title_normalizado  \
# 0                       strobo mini kit com  strobos
# 1                     filtro hoya hmc          hmc
# 2                 dvd next lite  envio toda segunda
# 3  fim   curso tubinho    motor desl  peccinin li...
# 4  carro infantil smart baby reclinável bandeiran...
#
#                             title_normalizado_sem_sw  \
# 0                            strobo mini kit strobos
# 1                                filtro hoya hmc hmc
# 2                   dvd next lite envio toda segunda
# 3  fim curso tubinho motor desl peccinin light super
# 4  carro infantil smart baby reclinável bandeiran...
#
#                 title_normalizado_sem_sw_stemmer
# 0                            strob min kit strob
# 1                              filtr hoy hmc hmc
# 2                   dvd next lit envi tod segund
# 3  fim curs tubinh motor desl peccinin light sup
# 4    carr infantil smart baby reclin bandeir ros

# %% [markdown]
# ### 2.5 - Balancear Dados com Uper-Undersampling

# %%
def balencearMesmaClasse(df_desbalanceado,tamanho):
        
    lista_categorias = df_desbalanceado.category.unique()
        
    df_sampled = pd.DataFrame()

    for categoria in lista_categorias:

        df_tmp = df_desbalanceado[df_desbalanceado.category == categoria]

        if(len(df_tmp)) > tamanho:
            ##como a classe tem mais registros que o tamanho, fazer SEM repeticao
            df_tmp = resample(df_tmp, 
                             replace=False,    
                             n_samples=(tamanho),    
                             random_state=123) 
        else:
            ##como a classe tem mais registros que o tamanho, fazer COM repeticao
            df_tmp = resample(df_tmp, 
                             replace=True,    
                             n_samples=(tamanho),    
                             random_state=123)

        df_sampled = pd.concat([df_sampled, df_tmp])

    return df_sampled

# %%
dataset_balanceado = balencearMesmaClasse(dataset,370)
dataset_balanceado.head(5)
# Out:
#                                                    title     category  \
# 20135  balde de gelo acrílico p/ cerveja 5l baldinho ...  ice_buckets
# 3343   cervegela c/ refil de congelamento 2h mantém c...  ice_buckets
# 24862        balde brahma com alça e abridor de garrafas  ice_buckets
# 14064  kit c/ 6 balde plástico reforçado plasnew 20 l...  ice_buckets
# 27396           **balde brahma  - luminoso de brinde!!!!  ice_buckets
#
#                                        title_normalizado  \
# 20135  balde   gelo acrílico    cerveja   baldinho ge...
# 3343   cervegela    refil   congelamento   mantém cer...
# 24862         balde brahma com alça   abridor   garrafas
# 14064   kit     balde plástico reforçado plasnew  litros
# 27396              balde brahma    luminoso   brinde
#
#                                 title_normalizado_sem_sw  \
# 20135    balde gelo acrílico cerveja baldinho gelo latas
# 3343   cervegela refil congelamento mantém cerveja ge...
# 24862                 balde brahma alça abridor garrafas
# 14064        kit balde plástico reforçado plasnew litros
# 27396                       balde brahma luminoso brinde
#
#               title_normalizado_sem_sw_stemmer
# 20135    bald gel acríl cervej baldinh gel lat
# 3343   cervegel refil congel mantém cervej gel
# 24862           bald brahm alça abridor garraf
# 14064     kit bald plástic reforc plasnew litr
# 27396                   bald brahm lumin brind

# %%
dataset_balanceado.shape
# Out:
# (30710, 5)

# %%
dataset.shape
# Out:
# (33500, 5)

# %%
###Separar os dados em treino e teste """
X_train, X_test, y_train, y_test = train_test_split(dataset_balanceado["title_normalizado_sem_sw_stemmer"], 
                                                    dataset_balanceado["category"], 
                                                    test_size=0.3, random_state = 0)

#CONSTRUIR MATRIZ ESPARSA """ 
count_vect = CountVectorizer(max_df= 0.5,
                            max_features= None,
                            min_df= 1,
                            ngram_range= (1, 2))

#fazer fit_transoform (vetor de palavras) para os dados de treino """
X_train_counts = count_vect.fit_transform(X_train)

#ponderar palavras mais frequentes  """
tf_transformer = TfidfTransformer(norm= 'l2',
                                  use_idf= True)
X_train_tf = tf_transformer.fit_transform(X_train_counts)

'''
Melhor score: 0.956
Melhores Parametros:
	clf__alpha: 1e-05
	clf__max_iter: 80
	clf__penalty: 'l2'
	tfidf__norm: 'l2'
	tfidf__use_idf: True
	vect__max_df: 0.5
	vect__max_features: None
	vect__min_df: 1
	vect__ngram_range: (1, 2)
       '''
# Out:
# "\nMelhor score: 0.956\nMelhores Parametros:\n\tclf__alpha: 1e-05\n\tclf__max_iter: 80\n\tclf__penalty: 'l2'\n\ttfidf__norm: 'l2'\n\ttfidf__use_idf: True\n\tvect__max_df: 0.5\n\tvect__max_features: None\n\tvect__min_df: 1\n\tvect__ngram_range: (1, 2)\n       "

# %% [markdown]
# ## Etapa 3 - Aplicar aprendizado de máquina

# %%
sgd = SGDClassifier(penalty='l2',
                    alpha=1e-05, 
                    max_iter=80)



#treinar modelo
t0 = time()
clf = sgd.fit(X_train_tf, y_train)
print("Fit done in %0.3fs" % (time() - t0))
y_pred_modelo = clf.predict(count_vect.transform(X_test))
print("Pred done in %0.3fs" % (time() - t0))
# Out:
# Fit done in 1.101s
# Pred done in 1.249s

# %% [markdown]
# ### Calcular desempenho

# %%
saida = classification_report(y_test, y_pred_modelo, target_names=dataset_balanceado["category"].unique(),output_dict=True)
dfResultado = pd.DataFrame(saida).transpose()
df
# Out:
#                                 f1-score  precision    recall      support
# ice_buckets                     0.903226   0.954545  0.857143    98.000000
# thermal_cups_and_tumblers       0.937799   0.933333  0.942308   104.000000
# stabilizers_and_ups             0.927928   0.919643  0.936364   110.000000
# led_stage_lights                0.930041   0.918699  0.941667   120.000000
# lens_filters                    0.990476   0.990476  0.990476   105.000000
# engine_oil_dipsticks            0.928230   0.932692  0.923810   105.000000
# roller_skates                   0.973214   0.981982  0.964602   113.000000
# pool_lights                     0.916667   0.933962  0.900000   110.000000
# key_racks                       0.889831   0.921053  0.860656   122.000000
# tv_antennas                     0.897778   0.885965  0.909910   111.000000
# motorcycle_fenders              0.924528   0.924528  0.924528   106.000000
# soldering_machines              0.931507   0.935780  0.927273   110.000000
# motorcycle_batteries            0.953191   0.925620  0.982456   114.000000
# car_distributor_caps            0.942149   0.926829  0.957983   119.000000
# dj_controllers                  0.942222   0.963636  0.921739   115.000000
# av_receivers                    0.928571   0.919192  0.938144    97.000000
# musical_tuners                  0.940000   0.895238  0.989474    95.000000
# tool_boxes                      0.973214   0.981982  0.964602   113.000000
# electronic_entrance_intercoms   0.967213   0.983333  0.951613   124.000000
# sway_bars                       0.987448   1.000000  0.975207   121.000000
# gate_motors                     0.961039   0.973684  0.948718   117.000000
# home_shelves                    0.953586   0.974138  0.933884   121.000000
# erotic_pumps                    0.916667   0.909091  0.924370   119.000000
# motorcycle_jerseys              0.971698   0.953704  0.990385   104.000000
# aquarium_filters                0.985782   1.000000  0.971963   107.000000
# car_engine_camshafts            0.986900   0.982609  0.991228   114.000000
# clutch_forks                    0.921739   0.963636  0.883333   120.000000
# cellphone_repair_tool_kits      0.932735   0.888889  0.981132   106.000000
# party_hats                      0.986900   0.982609  0.991228   114.000000
# bookcases                       0.995215   1.000000  0.990476   105.000000
# ...                                  ...        ...       ...          ...
# toothpastes                     0.959677   0.952000  0.967480   123.000000
# gps                             0.964824   0.950495  0.979592    98.000000
# hand_polishers                  0.983051   0.983051  0.983051   118.000000
# cd_and_dvd_players              0.975369   0.961165  0.990000   100.000000
# gun_holsters                    0.967742   0.972222  0.963303   109.000000
# cribs                           0.936585   0.914286  0.960000   100.000000
# toilet_seats                    0.940678   0.956897  0.925000   120.000000
# sofa_and_futon_covers           0.890830   0.836066  0.953271   107.000000
# engine_cooling_fan_motors       0.932127   0.953704  0.911504   113.000000
# pants                           0.967442   0.990476  0.945455   110.000000
# baby_car_seats                  0.965517   0.989899  0.942308   104.000000
# car_ac_hose_assemblies          0.987448   0.983333  0.991597   119.000000
# straws                          0.956938   0.980392  0.934579   107.000000
# gym_gloves                      0.975610   0.967742  0.983607   122.000000
# car_engine_camshaft_sensors     0.969163   0.948276  0.990991   111.000000
# kitchen_range_hoods             0.982456   0.965517  1.000000   112.000000
# erotic_costumes                 0.954955   0.929825  0.981481   108.000000
# padlocks                        0.982301   0.991071  0.973684   114.000000
# dried_fruits                    0.975369   0.961165  0.990000   100.000000
# dog_carriers_and_carrying_bags  0.978723   0.974576  0.982906   117.000000
# push_and_riding_toys            0.914573   0.883495  0.947917    96.000000
# car_intercoolers                0.866359   0.940000  0.803419   117.000000
# power_steering_hoses            0.920354   0.920354  0.920354   113.000000
# toothbrushes                    0.954315   0.959184  0.949495    99.000000
# desktop_computer_cases          0.945946   0.937500  0.954545   110.000000
# scooters                        0.935622   0.915966  0.956140   114.000000
# microcontrollers                0.967213   0.967213  0.967213   122.000000
# accuracy                        0.950071   0.950071  0.950071     0.950071
# macro avg                       0.949620   0.950582  0.949767  9213.000000
# weighted avg                    0.950017   0.951047  0.950071  9213.000000
#
# [86 rows x 4 columns]

# %%
## Mostar menores desempenhos
df[df["precision"] < 0.90 ]
# Out:
#                             f1-score  precision    recall  support
# tv_antennas                 0.897778   0.885965  0.909910    111.0
# musical_tuners              0.940000   0.895238  0.989474     95.0
# cellphone_repair_tool_kits  0.932735   0.888889  0.981132    106.0
# lighters                    0.876712   0.872727  0.880734    109.0
# flutes                      0.828829   0.793103  0.867925    106.0
# sofa_and_futon_covers       0.890830   0.836066  0.953271    107.0
# push_and_riding_toys        0.914573   0.883495  0.947917     96.0

# %%
##Acuracia global
accuracy_score(y_test, y_pred_modelo)
# Out:
# 0.950070552480191

# %% [markdown]
# # Aplicar modelo nos dados de Teste

# %%
##Visao dos dados de Teste
datasetTeste.head(5)
# Out:
#                                                title  id  \
# 0                      strobo mini kit com 5 strobos   0
# 1                filtro hoya hmc uv(c) - uv-hmc 72mm   1
# 2                 dvd next lite (envio toda segunda)   2
# 3  fim de curso tubinho do  motor desl  peccinin ...   3
# 4  carro infantil smart baby reclinável bandeiran...   4
#
#                                    title_normalizado  \
# 0                       strobo mini kit com  strobos
# 1                     filtro hoya hmc          hmc
# 2                 dvd next lite  envio toda segunda
# 3  fim   curso tubinho    motor desl  peccinin li...
# 4  carro infantil smart baby reclinável bandeiran...
#
#                             title_normalizado_sem_sw  \
# 0                            strobo mini kit strobos
# 1                                filtro hoya hmc hmc
# 2                   dvd next lite envio toda segunda
# 3  fim curso tubinho motor desl peccinin light super
# 4  carro infantil smart baby reclinável bandeiran...
#
#                 title_normalizado_sem_sw_stemmer
# 0                            strob min kit strob
# 1                              filtr hoy hmc hmc
# 2                   dvd next lit envi tod segund
# 3  fim curs tubinh motor desl peccinin light sup
# 4    carr infantil smart baby reclin bandeir ros

# %% [markdown]
# ### Aplicando predição

# %%
y_pred_modelo_final = clf.predict(count_vect.transform(datasetTeste["title_normalizado_sem_sw_stemmer"]))

# %%
data_setPredito = pd.DataFrame(y_pred_modelo_final,columns=["category"])
data_setPredito.head(10)
# Out:
#                     category
# 0           led_stage_lights
# 1               lens_filters
# 2         cd_and_dvd_players
# 3                gate_motors
# 4                   scooters
# 5       power_steering_hoses
# 6      sofa_and_futon_covers
# 7             musical_tuners
# 8  tv_receivers_and_decoders
# 9            erotic_costumes

# %%
##Transformar em Data-Frame
data_setPredito['id'] = data_setPredito.index
data_setPredito['category'] = data_setPredito['category'].str.upper()
submissao = data_setPredito[["id","category"]] 

## Salvar no formato de submissao 
submissao.to_csv("submissao.csv", index = None, header=True)
submissao.head(10)
# Out:
#    id                   category
# 0   0           LED_STAGE_LIGHTS
# 1   1               LENS_FILTERS
# 2   2         CD_AND_DVD_PLAYERS
# 3   3                GATE_MOTORS
# 4   4                   SCOOTERS
# 5   5       POWER_STEERING_HOSES
# 6   6      SOFA_AND_FUTON_COVERS
# 7   7             MUSICAL_TUNERS
# 8   8  TV_RECEIVERS_AND_DECODERS
# 9   9            EROTIC_COSTUMES

# %% [markdown]
# ### Gerando visualizacão amigável

# %%
visualizacaoResutado =   pd.merge(datasetTeste[["title","title_normalizado_sem_sw","title_normalizado_sem_sw_stemmer","id"]],
                         data_setPredito[["id","category"]],
                         on='id')
visualizacaoResutado.head(200)
# Out:
#                                                  title  \
# 0                        strobo mini kit com 5 strobos
# 1                  filtro hoya hmc uv(c) - uv-hmc 72mm
# 2                   dvd next lite (envio toda segunda)
# 3    fim de curso tubinho do  motor desl  peccinin ...
# 4    carro infantil smart baby reclinável bandeiran...
# 5    par coifa caixa direção hidraulica c4 lounge 2...
# 6    protetor sofá retrátil reclinavél com assento ...
# 7             pedal behringer tu300 afinador cromatico
# 8                               receptor satmax elsys
# 9                               mini fantasia noivinha
# 10   rede p/proteção de cama elastica 4.00 mts c/2 ...
# 11   coldre cueca + abdominal elástico axilar velad...
# 12   placa de comando para motor de portão  rcg com...
# 13                        casa de cachorro linguiçinha
# 14   carregador de bateria lp-e5 canon eos 450d 500...
# 15   fonte carregador original sony ac-l200 dcr-hc5...
# 16   camera traseira g4 play xt1626 original retira...
# 17                 motor arranque cbx 250 twister 2007
# 18   flauta transversal harmony tbfl-6248.em dó c/c...
# 19   gaiola comando valvula prisma cobalt spin 1.4 ...
# 20   kit c/ 2 creme dental close up white attractio...
# 21      3 jogo de banheiro tear pintado 3 pcs atacado
# 22   calço carroceria (coxinho) pu 1 pol rural pick...
# 23    cabo de embreagem honda crf 230 todas - br parts
# 24                rastreador sem mensalidade fortaleza
# 25   antena sinal digital para televisão, pronta en...
# 26   kit carenagem com protetor xre 300 branco pero...
# 27      denon avr 591 - high resolution surround sound
# 28       capa protetora de sofá 3 e 2 lugares vermelho
# 29                       escova dental torcedor santos
# ..                                                 ...
# 170  kit rolamento roda traseiro kia besta 92/04 as...
# 171  retentor valvula + cabeçote    amarok tdi (201...
# 172           flex camera frontal motorola moto c plus
# 173      funil vareta do nivel de oleo polo 06a103663a
# 174                                 calça jeans hiatto
# 175  camiseta alpinestars feminina ageless tank pre...
# 176  mini veiculo pick-up elétrica guchao grande - ...
# 177                camiseta dakar dust rider off white
# 178  caixa mini maçarico 40 unidades recarregavel t...
# 179  berço mini cama baby branco brilho, padrão ame...
# 180  kit interfone coletivo intelbras 38 pontos com...
# 181         coldre tático nylon 24/7 uso velado /preto
# 182           guarda pó do garfo da embreagem do opala
# 183  growler 2l  lei da pureza  para  chopp e cerve...
# 184  aparelho bomba peniana controle anel ce capa p...
# 185  kit antena mini maria mole + par. fixador + su...
# 186                3 vaporizadores de ervas gpen elite
# 187  kit refletor piscina 3 iluminação led 45 color...
# 188  porteiro eletrônico residencial ipr8000 intelb...
# 189  tampa de vaso square preto para bacia incepa c...
# 190       garfo do câmbio do niva e laika - peças lada
# 191  intercooler volkswagen 16-220 4x2 cum 6ctaa 22...
# 192              cofre gatinho ladrão (pronta entrega)
# 193  kit 15 sungas boxer adulto moda praia lycra at...
# 194  carregador super rápido bap-551 com 4 baterias...
# 195  promoção capa protetor de sofa  2 e 3 lugares ...
# 196  dvd aikon akdv-3000 dvd/ cd/ mp3/ mp4/ usb/ wm...
# 197  virabrequim kia cerato 1.6 16v 2014 a 2015 - 3...
# 198                                   caldeira ws-2035
# 199               patins rolller proficional numero 34
#
#                               title_normalizado_sem_sw  \
# 0                              strobo mini kit strobos
# 1                                  filtro hoya hmc hmc
# 2                     dvd next lite envio toda segunda
# 3    fim curso tubinho motor desl peccinin light super
# 4    carro infantil smart baby reclinável bandeiran...
# 5            par coifa caixa direção hidraulica lounge
# 6    protetor sofá retrátil reclinavél assento módulos
# 7             pedal behringer tu300 afinador cromatico
# 8                                receptor satmax elsys
# 9                               mini fantasia noivinha
# 10          rede proteção cama elastica mts mts altura
# 11   coldre cueca abdominal elástico axilar velado ...
# 12         placa comando motor portão rcg rcg original
# 13                           casa cachorro linguiçinha
# 14                   carregador bateria canon eos lpe5
# 15   fonte carregador original sony l200 dcr hc52e ...
# 16   camera traseira play xt1626 original retirada ...
# 17                          motor arranque cbx twister
# 18        flauta transversal harmony tbfl case hendrix
# 19             gaiola comando lvula prisma cobalt spin
# 20    kit creme dental close white attraction platinum
# 21              jogo banheiro tear pintado pcs atacado
# 22             calço carroceria coxinho pol rural pick
# 23                cabo embreagem honda crf todas parts
# 24                    rastreador mensalidade fortaleza
# 25       antena sinal digital televisão pronta entrega
# 26             kit carenagem protetor xre branco perol
# 27            denon avr high resolution surround sound
# 28                capa protetora sofá lugares vermelho
# 29                         esco dental torcedor santos
# ..                                                 ...
# 170   kit rolamento roda traseiro kia besta asia topic
# 171          retentor lvula cabeçote amarok tdi diesel
# 172             flex camera frontal motorola moto plus
# 173                funil reta nivel oleo polo a103663a
# 174                                 calça jeans hiatto
# 175  camiseta alpinestars feminina ageless tank pre...
# 176  mini veiculo pick elétrica guchao grande peg p...
# 177                camiseta dakar dust rider off white
# 178  caixa mini maçarico unidades recarregavel tran...
# 179  berço mini cama baby branco brilho padrão amer...
# 180  kit interfone coletivo intelbras pontos fechad...
# 181               coldre tático nylon uso velado preto
# 182                       guarda garfo embreagem opala
# 183         growler lei pureza chopp cerveja artesanal
# 184  aparelho bomba peniana controle anel capa peniana
# 185  kit antena mini maria mole par fixador sup por...
# 186                             porizadores gpen elite
# 187  kit refletor piscina iluminação led colorido c...
# 188  porteiro eletrônico residencial ipr8000 intelbras
# 189        tampa square preto bacia incepa cidamar lpf
# 190                      garfo câmbio laika peças lada
# 191             intercooler volkswagen cum ctaa diesel
# 192                cofre gatinho ladrão pronta entrega
# 193  kit sungas boxer adulto moda praia lycra ataca...
# 194           carregador super rápido bap baterias mah
# 195  promoção capa protetor sofa lugares envio imed...
# 196           dvd aikon akdv dvd mp3 mp4 usb wma caixa
# 197                             virabrequim kia cerato
# 198                                           caldeira
# 199                  patins rolller proficional numero
#
#                       title_normalizado_sem_sw_stemmer   id  \
# 0                                  strob min kit strob    0
# 1                                    filtr hoy hmc hmc    1
# 2                         dvd next lit envi tod segund    2
# 3        fim curs tubinh motor desl peccinin light sup    3
# 4          carr infantil smart baby reclin bandeir ros    4
# 5                   par coif caix direçã hidraul loung    5
# 6        protetor sof retrátil reclinavél assent módul    6
# 7                      pedal behring tu300 afin cromat    7
# 8                                receptor satmax elsys    8
# 9                                   min fantas noivinh    9
# 10                 red proteçã cam elast mts mts altur   10
# 11          coldr cuec abdominal elást axil vel escond   11
# 12               plac com motor portã rcg rcg original   12
# 13                              cas cachorr linguiçinh   13
# 14                           carreg bat canon eos lpe5   14
# 15   font carreg original sony l200 dcr hc52e dcrhc...   15
# 16      cam traseir play xt1626 original retir aparelh   16
# 17                             motor arranqu cbx twist   17
# 18          flaut transversal harmony tbfl cas hendrix   18
# 19                    gaiol com lvul prism cobalt spin   19
# 20       kit crem dental clos whit attraction platinum   20
# 21                      jog banheir tear pint pcs atac   21
# 22                   calc carroc coxinh pol rural pick   22
# 23                      cab embreag hond crf tod parts   23
# 24                            rastreador mensal fortal   24
# 25           anten sinal digital televisã pront entreg   25
# 26                kit carenag protetor xre branc perol   26
# 27            denon avr high resolution surround sound   27
# 28                        cap protetor sof lug vermelh   28
# 29                           esco dental torcedor sant   29
# ..                                                 ...  ...
# 170        kit rolament rod traseir kia best asi topic  170
# 171            retentor lvul cabeçot amarok tdi diesel  171
# 172                  flex cam frontal motorol mot plus  172
# 173                   funil ret nivel ole pol a103663a  173
# 174                                   calc jeans hiatt  174
# 175  camiset alpinestars feminin ageless tank pret rs1  175
# 176        min veicul pick elétr gucha grand peg pereg  176
# 177                      camiset dak dust rid off whit  177
# 178     caix min maçar unidad recarregavel transparent  178
# 179       berc min cam baby branc brilh padrã american  179
# 180       kit interfon colet intelbr pont fechadur imã  180
# 181                     coldr tátic nylon uso vel pret  181
# 182                            guard garf embreag opal  182
# 183             growl lei purez chopp cervej artesanal  183
# 184        aparelh bomb penian control anel cap penian  184
# 185     kit anten min mar mol par fixador sup port mal  185
# 186                                    poriz gpen elit  186
# 187         kit refletor piscin ilumin led color coman  187
# 188        porteir eletrôn residencial ipr8000 intelbr  188
# 189                tamp squar pret bac incep cidam lpf  189
# 190                            garf câmbi laik pec lad  190
# 191                intercool volkswagen cum cta diesel  191
# 192                     cofr gatinh ladrã pront entreg  192
# 193       kit sung box adult mod pra lycra atac revend  193
# 194                         carreg sup ráp bap bat mah  194
# 195          promoçã cap protetor sof lug envi imediat  195
# 196            dvd aikon akdv dvd mp3 mp4 usb wma caix  196
# 197                              virabrequim kia cerat  197
# 198                                            caldeir  198
# 199                     patins rolll proficional numer  199
#
#                            category
# 0                  LED_STAGE_LIGHTS
# 1                      LENS_FILTERS
# 2                CD_AND_DVD_PLAYERS
# 3                       GATE_MOTORS
# 4                          SCOOTERS
# 5              POWER_STEERING_HOSES
# 6             SOFA_AND_FUTON_COVERS
# 7                    MUSICAL_TUNERS
# 8         TV_RECEIVERS_AND_DECODERS
# 9                   EROTIC_COSTUMES
# 10                  PROTECTION_NETS
# 11                     GUN_HOLSTERS
# 12                      GATE_MOTORS
# 13   DOG_CARRIERS_AND_CARRYING_BAGS
# 14                  CAMERA_CHARGERS
# 15                  CAMERA_CHARGERS
# 16    CELLPHONE_REPLACEMENT_CAMERAS
# 17        MOTORCYCLE_STARTER_MOTORS
# 18                           FLUTES
# 19             CAR_ENGINE_CAMSHAFTS
# 20                      TOOTHPASTES
# 21                      TOILET_RUGS
# 22                            PANTS
# 23            VEHICLE_CLUTCH_CABLES
# 24                              GPS
# 25                      TV_ANTENNAS
# 26               MOTORCYCLE_FENDERS
# 27                     AV_RECEIVERS
# 28            SOFA_AND_FUTON_COVERS
# 29                     TOOTHBRUSHES
# ..                              ...
# 170                 WHEELS_BEARINGS
# 171  ENGINE_VALVES_SPRING_RETAINERS
# 172   CELLPHONE_REPLACEMENT_CAMERAS
# 173            ENGINE_OIL_DIPSTICKS
# 174                           PANTS
# 175              MOTORCYCLE_JERSEYS
# 176            PUSH_AND_RIDING_TOYS
# 177              MOTORCYCLE_JERSEYS
# 178                        LIGHTERS
# 179                           CRIBS
# 180   ELECTRONIC_ENTRANCE_INTERCOMS
# 181                    GUN_HOLSTERS
# 182                    CLUTCH_FORKS
# 183                     ICE_BUCKETS
# 184                    EROTIC_PUMPS
# 185                     TV_ANTENNAS
# 186                           IRONS
# 187                     POOL_LIGHTS
# 188   ELECTRONIC_ENTRANCE_INTERCOMS
# 189                    TOILET_SEATS
# 190                    CLUTCH_FORKS
# 191                CAR_INTERCOOLERS
# 192                MICROCONTROLLERS
# 193                    MEN_SWIMWEAR
# 194                BATTERY_CHARGERS
# 195           SOFA_AND_FUTON_COVERS
# 196              CD_AND_DVD_PLAYERS
# 197                     CRANKSHAFTS
# 198                           IRONS
# 199                   ROLLER_SKATES
#
# [200 rows x 5 columns]

# %% [markdown]
# # FIM

# %%
dataset_balanceado[ dataset_balanceado["category"] == 'flutes']
# Out:
#                                                    title category  \
# 10070  flauta transversal  king , americana prateada,...   flutes
# 24009  flauta slade transversal prata ccb em dó promoção   flutes
# 1576                       flauta indígena tipo chaveiro   flutes
# 8439   flauta transversal michael niquelada com pé em dó   flutes
# 11202                 flautim picollo eb 6 chaves antigo   flutes
# 13029  flauta doce escolar para criança aprender toca...   flutes
# 6511                     flauta transversal  eagle fl05s   flutes
# 22506          flauta transversal tm51ni niquelada - csr   flutes
# 23379  flauta artesanado profissional musico bambu  t...   flutes
# 9974          flauta transversal artley 8.0 prata maciça   flutes
# 12063  gravador de soprano destacável srg-405 da suzu...   flutes
# 13388  flauta doce  soprano barroca zion híbrida made...   flutes
# 4585      flauta eagle fl03s prateada transversal dó  br   flutes
# 7943   flauta transversal yamaha   maleta luxo promoç...   flutes
# 3219                                   irish flute em dó   flutes
# 23340                      bocal para flauta burkart 998   flutes
# 11892  vareta de madeira flauta transversal afinação ...   flutes
# 26669  flauta tranversal  e.l.defort open hole super ...   flutes
# 9974          flauta transversal artley 8.0 prata maciça   flutes
# 21487  flauta doce soprano germânica yrs 23 g - yamah...   flutes
# 7516            flauta transversal yamaha yfl 271sl nova   flutes
# 32577  flauta transversal yamaha made in japan yfl-45...   flutes
# 33099                 flauta yamaha 211 sl made in japan   flutes
# 255    flauta infantil mickey/carros/toy store disney...   flutes
# 3910   stopper patenteado cbecker aluminio titanium -...   flutes
# 8704       flauta doce soprano germânica c yrs23g yamaha   flutes
# 4585      flauta eagle fl03s prateada transversal dó  br   flutes
# 17804                     flauta trasversal/ eagle-fl03s   flutes
# 13809  flauta doce germanica phx verde c/ capa e vara...   flutes
# 10220  flauta transversa pífano/pífe  de bambu  em g(...   flutes
# ...                                                  ...      ...
# 19641                  flauta transversal swallow sfl_56   flutes
# 20641                        flauta chinesa dizi ( nova)   flutes
# 22720   flauta doce yamaha soprano yrs20bb azul - fl0009   flutes
# 24251        flauta doce yamaha barroca - nova c/ estojo   flutes
# 15354  flauta doce soprano barroca azul custom sound ...   flutes
